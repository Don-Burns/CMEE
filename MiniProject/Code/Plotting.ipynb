# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import scipy as sc

# %% [markdown]
# # Plotting
# run through all IDs and plot for each ID.  Save the out put to `Results/plots`.
#
# Plotting is supressed here for speed.

# %%
data = pd.read_csv("../data/CRat.csv")

# %%
for i in data.ID.unique():
    plt.ioff()
    print(i)
    tmpSubset = data[data["ID"] == i]
#     fig = sns.lmplot("ResDensity", "N_TraitValue", data = tmpSubset, fit_reg=False)
#     fig.savefig("../Results/{}.jpeg".format(i))
#     plt.close("all")
# Out:
# 39835
# 39836
# 39837
# 39838
# 39839
# 39840
# 39841
# 39842
# 39843
# 39844
# 39845
# 39846
# 39847
# 39848
# 39849
# 39850
# 39851
# 39852
# 39853
# 39854
# 39855
# 39856
# 39857
# 39858
# 39859
# 39860
# 39861
# 39862
# 39863
# 39864
# 39865
# 39866
# 39867
# 39868
# 39869
# 39870
# 39871
# 39873
# 39874
# 39875
# 39876
# 39877
# 39878
# 39879
# 39880
# 39881
# 39882
# 39883
# 39884
# 39885
# 39886
# 39887
# 39888
# 39889
# 39890
# 39891
# 39892
# 39893
# 39894
# 39895
# 39896
# 39897
# 39898
# 39899
# 39900
# 39901
# 39902
# 39903
# 39904
# 39905
# 39906
# 39907
# 39908
# 39909
# 39910
# 39911
# 39912
# 39913
# 39914
# 39915
# 39916
# 39917
# 39918
# 39919
# 39920
# 39921
# 39922
# 39923
# 39924
# 39925
# 39926
# 39927
# 39928
# 39929
# 39931
# 39932
# 39933
# 39934
# 39935
# 39936
# 39937
# 39938
# 39939
# 39940
# 39941
# 39942
# 39943
# 39944
# 39945
# 39946
# 39947
# 39948
# 39949
# 39950
# 39951
# 39952
# 39953
# 39954
# 39955
# 39956
# 39957
# 39958
# 39959
# 39960
# 39961
# ...

# %% [markdown]
# ### Some Exploration of more dodgey IDs
#
# Just need to change the ID in line one to look at the N_TraitValue

# %%
subset = data[data["ID"] == 39981]
subset["N_TraitValue"].head()
# Out:
# 1546    0.000028
# 1547    0.000035
# 1548    0.000035
# 1549    0.000050
# 1550    0.000046
# Name: N_TraitValue, dtype: float64
